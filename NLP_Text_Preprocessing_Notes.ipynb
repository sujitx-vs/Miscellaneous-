# %% [markdown]
# <a href="https://colab.research.google.com/github/sujitx-vs/Miscellaneous-/blob/main/NLP_Text_Preprocessing_Notes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # NLP Text Preprocessing
#
# Ready-to-use Google Colab notebook based on your notes.

# %% [markdown]
# ## Install (if needed)

# %%
# !pip -q install nltk textblob emoji spacy
import nltk
nltk.download('stopwords')
nltk.download('punkt_tab' if False else 'punkt')
nltk.download('wordnet')
nltk.download('omw-1.4')

# %% [markdown]
# ## Basic Preprocessing
# ### Lowercasing

# %%
text='Hello WORLD!'
print(text.lower())

# %% [markdown]
# ### Remove HTML Tags

# %%
import re
def remove_html_tags(text):
    return re.sub(r'<.*?>','',text)
print(remove_html_tags('<p>Hello</p>'))

# %% [markdown]
# ### Remove URLs

# %%
def remove_url(text):
    return re.sub(r'https?://\S+|www\.\S+','',text)
print(remove_url('Visit https://google.com now'))

# %% [markdown]
# ### Remove Punctuation

# %%
import string
exclude=string.punctuation
def remove_punc(text):
    return text.translate(str.maketrans('','',exclude))
print(remove_punc("Hello, World!"))

# %% [markdown]
# ### Chat Word Conversion

# %%
chat_words={'IMO':'in my opinion','GN':'good night','POV':'point of view'}
def chat_conv(text):
    return ' '.join(chat_words.get(w.upper(),w) for w in text.split())
print(chat_conv('GN friends IMO'))

# %% [markdown]
# ### Spelling Correction

# %%
from textblob import TextBlob
print(TextBlob('I havv a catt').correct())

# %% [markdown]
# ### Remove Stopwords

# %%
from nltk.corpus import stopwords
sw=set(stopwords.words('english'))
def remove_stopwords(text):
    return ' '.join(w for w in text.split() if w.lower() not in sw)
print(remove_stopwords('this is a sample sentence'))

# %% [markdown]
# ### Emoji Handling

# %%
import emoji
print(emoji.demojize('Python is 🔥'))

# %% [markdown]
# ## Advanced Preprocessing
# ### Tokenization

# %%
from nltk.tokenize import word_tokenize,sent_tokenize
text='Hello world. NLP is fun!'
print(word_tokenize(text))
print(sent_tokenize(text))

# %% [markdown]
# ### Stemming

# %%
from nltk.stem import PorterStemmer
ps=PorterStemmer()
print([ps.stem(w) for w in ['walk','walking','walked','walks']])

# %% [markdown]
# ### Lemmatization

# %%
from nltk.stem import WordNetLemmatizer
lem=WordNetLemmatizer()
print([lem.lemmatize(w) for w in ['cars','wolves','running']])
